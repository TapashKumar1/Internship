# %% [markdown]
# Importing the necesssary libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Getting the dataset

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\baseball.csv")

# %% [markdown]
# Exploratory Data Analysis(Non-Graphical)

# %%
# Will print all the 30 rows in the dataset
data.head(30)
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# The dataset is clean with no null values

# %%
data.shape
# Out:
# (30, 17)

# %% [markdown]
# The dataset contains 30 rows and 17 columns

# %%
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Exploratory Data Analysis (Graphical)

# %%
win = data['W']
run_scored = data['R']
plt.figure(figsize=(10,8))
plt.scatter(run_scored,win,alpha=0.7)
plt.xlabel('Runs Scored (R)')
plt.ylabel('Wins (W)')
plt.title('Runs vs Wins Scatter Plot')
plt.grid(True)
plt.show()

# %% [markdown]
# Plotting Runs vs Wins scatter plot to show the relationship between a team's ability to score runs and their overall number of wins. It can help identify if more runs generally lead to more wins.

# %%
era = data['ERA']
plt.figure(figsize=(10,8))
plt.scatter(era,run_scored,alpha=0.7)
plt.xlabel('Earned Runs Average')
plt.ylabel('Runs')
plt.title('ERA vs R Scatter plot')
plt.grid(True)
plt.show()

# %% [markdown]
# Plotting ERA VS Runs to help visualize the relationship between a team's offensive performance (scoring runs) and their pitching performance (ERA). It can indicate how well a team's offense and defense are balanced.

# %%
hits = data['H']
plt.figure(figsize=(10,8))
plt.bar(data.index,hits,label = 'Hits (H)',alpha=0.7)
plt.bar(data.index,run_scored, label = 'Runs Scored (R)', alpha=0.7)
plt.xlabel('Team Index')
plt.ylabel('Count')
plt.title('Hits vs Runs Scored')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Plotting Hits Vs Runs Score to show how closely the number of hits is related to the number of runs scored. It can help determine if getting more hits leads to more runs.

# %%
home_runs = data['HR']
plt.figure(figsize=(10,8))
plt.plot(home_runs, run_scored, marker='o', linestyle='-', label = 'Home Runs vs Runs Scored')
plt.xlabel('Home Runs(HR)')
plt.ylabel('Runs Scored(R)')
plt.title('Home Runs vs Runs Scored')
plt.legend()
plt.show()

# %% [markdown]
# Visualization to illustrate the impact of home runs on a team's ability to score runs. It can help determine if hitting more home runs leads to more runs scored.

# %%
stolen_bases = data['SB']
plt.figure(figsize=(10,8))
plt.bar(range(len(stolen_bases)),win,color='purple',alpha=0.7,label='Wins')
plt.bar(range(len(stolen_bases)),stolen_bases,color='lightgreen',alpha=0.7,label='Stolen Bases')
plt.xlabel('Team')
plt.ylabel('Count')
plt.xticks(range(len(stolen_bases)),range(1,len(stolen_bases)+1))
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# This can explore whether a team's ability to steal bases is related to their overall number of wins. It can help determine if base stealing impacts a team's success.

# %%
errors = data['E']
plt.figure(figsize=(10,8))
plt.bar(range(len(errors)),win,color='red',alpha=0.7,label='Wins')
plt.bar(range(len(errors)),errors,color='coral',alpha=0.7,label='Errors')
plt.xlabel('Team')
plt.ylabel('Count')
plt.xticks(range(len(errors)),range(1,len(errors)+1))
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# This can show if the number of errors made by a team is associated with their number of wins, indicating how defense affects overall success.

# %%
top_teams = data.sort_values(by='W',ascending=False).head(5)
team_id = top_teams.index
wins = top_teams['W']
runs = top_teams['R']
plt.figure(figsize=(12,8))
plt.bar(team_id,wins,color='royalblue',label='Wins',alpha=0.7)
plt.xlabel('Team')
plt.ylabel('Wins')
plt.title('Top 5 teams by Wins and Runs Scored')
plt.legend(loc='upper left')
plt.twinx()
plt.plot(team_id,runs,color='orange',label='Runs',linestyle='-',markersize=8)
plt.ylabel('Runs Scored(R)')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Checking for skewness in the columns 
data.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# These columns have a higher skewness '2B', 'HR', 'SO', 'SB', 'CG', 'SHO', 'SV', 'E'

# %%
# Treating skewness with box-cox transformation 
from scipy.stats import boxcox
skewed_features = ['2B', 'HR', 'SO', 'SB', 'CG', 'SHO', 'SV', 'E']
for feature in skewed_features:  
    transformed_feature, lambda_value = boxcox(data[feature] + 1)
    data[feature] = transformed_feature
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
axes = axes.flatten()
for i, feature in enumerate(skewed_features):
    axes[i].hist(data[feature], bins=20, color='purple', alpha=0.7)
    axes[i].set_title(f'Transformed {feature} Distribution')
plt.tight_layout()
plt.show()

# %%
# Plotting a correlation matrix to check the relationship between variables
corr_matrix = data.corr()
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f',linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Creating a Model

# %% [markdown]
# Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import mean_squared_error,r2_score

# %%
x = data.drop('W',axis=1)
y = data['W']
model = LinearRegression()
loo = LeaveOneOut()
mse_list = []
for train_index,test_index in loo.split(x):
    x_train,x_test = x.iloc[train_index],x.iloc[test_index]
    y_train,y_test = y.iloc[train_index],y.iloc[test_index]
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    mse = mean_squared_error(y_test,y_pred)
    mse_list.append(mse)
avg_mse = np.mean(mse_list)
print(f"Average Mean Squared Error (MSE) using Leave One Out: {avg_mse}")
# Out:
# Average Mean Squared Error (MSE) using Leave One Out: 29.436797518091495

# %% [markdown]
# Creating a different model
#
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=100)
model = RandomForestRegressor(random_state=100)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Squared Error (MSE): 37.355166666666705

# %% [markdown]
# out of the two models the Logistic Regression models gives us a better mean_squared_error score i.e. 29.43,the squared difference between the actual number of wins and the predicted number of wins by the model is 29.43. Whereas in RandomForest the mean_squared_error is 37.35.
